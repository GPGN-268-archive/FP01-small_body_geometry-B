# %%
import matplotlib
import plotly.graph_objects as go
import plotly.express as px
import pandas as pd
import numpy as np
from Data_functions import getData

# %%
points, vectors = getData('../data/obj/Psyche Hanuš.obj')

# %%
faces = np.array([points['x'][vectors['x'][:]-1], points['y'][vectors['y'][:]-1], points['z'][vectors['z'][:]-1]])
faces
# Out:
# array([[  0.264157,   0.264157,   0.264157, ...,   0.264157,   0.264157,
#           0.264157],
#        [  5.740792,  26.494492,   5.740792, ...,   5.740792, -13.268708,
#           5.740792],
#        [ 76.53256 ,  80.02926 ,  84.26186 , ..., -83.11054 , -75.66074 ,
#         -71.05814 ]])

# %%
df = pd.DataFrame(faces)
df
# Out:
#          0          1          2          3          4          5    \
# 0   0.264157   0.264157   0.264157   0.264157  20.691957  27.726857
# 1   5.740792  26.494492   5.740792 -14.626408   5.740792  26.494492
# 2  76.532560  80.029260  84.261860  82.347460  73.518360  82.347460
#
#          6          7          8          9    ...        790        791  \
# 0   0.264157   0.264157 -28.025143 -20.228443  ... -19.573043   0.264157
# 1  32.151992  45.570692   5.740792  35.627692  ... -21.385208 -21.385208
# 2  70.181260  71.154460  76.532560  76.386360  ... -71.820140 -75.660740
#
#          792        793        794        795        796        797  \
# 0   0.264157   0.264157  20.154757  20.154757   0.264157   0.264157
# 1 -31.368808 -20.811908 -20.811908   5.740792  27.546892   5.740792
# 2 -63.773140 -63.180540 -71.058140 -67.364240 -76.294940 -83.110540
#
#          798        799
# 0   0.264157   0.264157
# 1 -13.268708   5.740792
# 2 -75.660740 -71.058140
#
# ...

# %%
df.shape[1]
# Out:
# 800

# %%
a_f =(np.diff(df))

for i in len(a_f):
    a_f[i] = a_f[i] + faces[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 a_f =(np.diff(df))
# ----> 3 for i in len(a_f):
#       4     a_f[i] = a_f[i] + faces[i]
#
# TypeError: 'int' object is not iterable

# %%
fig = px.scatter_3d(x=a_f[0][:], y=a_f[1][:], z=a_f[2][:])
fig.show()
# Out:
# <div>                            <div id="db59550c-1b60-49e7-9926-c229fd8f057e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db59550c-1b60-49e7-9926-c229fd8f057e")) {                    Plotly.newPlot(                        "db59550c-1b60-49e7-9926-c229fd8f057e",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.0,0.0,0.0,20.427799999999998,7.0349,-27.462699999999998,0.0,-28.2893,7.796700000000001,0.0,-7.225800000000003,27.718400000000003,0.0,28.7925,-8.364700000000003,18.946,7.978900000000003,-19.890000000000004,0.1866000000000021,-27.6493,0.0,-28.4546,0.16529999999999845,-20.601
# ...
